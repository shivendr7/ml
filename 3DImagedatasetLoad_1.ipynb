# %% [markdown]
# <a href="https://colab.research.google.com/github/shivendr7/ml/blob/assignments/3DImagedatasetLoad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from tensorflow.keras.utils import get_file
url='http://3dshapenets.cs.princeton.edu/3DShapeNetsCode.zip'
path_to_zip=get_file('3DShapeNetsCode.zip', origin=url, extract=True)
# Out:
# ...
# 533454848/533450062 [==============================] - 34s 0us/step

# %%
path_to_zip
# Out:
# '/root/.keras/datasets/3DShapeNetsCode.zip'

# %%
# !ls /root/.keras/datasets/3DShapeNets/
# Out:
# 3D			     NBV_onestep_test.m
# bp			     README.md
# discriminative_10_class.mat  rec_completion_test.m
# discriminative_40_class.mat  rec_test.m
# generate_completions.m	     run_finetuning.m
# generative		     run_pretrain.m
# generative_10_class.mat      sample_test_classification.m
# generative_40_class.mat      sample_test_extreme.m
# kernels.m		     setup_paths.m
# kFunctions2.cu		     TSDF_recognition_test.m
# kFunctions2.ptx		     util
# kFunctions.cu		     volumetric_data
# kFunctions.ptx		     voxelization

# %%
# !ls /root/.keras/datasets/3DShapeNets/3D/
# Out:
# AngleAxis2RotationMatrix.m  icp.m		   RenderMex.mexa64
# chair.off		    off2im.m		   RenderMex.mexmaci64
# cubicle2col.m		    off_loader.m	   rgb_plane2rgb_world.m
# get_aligned_point_cloud.m   project3dPtsTo2d.m	   RotationMatrix2AngleAxis.m
# get_next_view.m		    read_3d_pts_general.m  sample2TSDF_fast.m
# get_points_in_bb3d.m	    RenderMex.cpp	   TSDF.m

# %%
# !ls /root/.keras/datasets/3DShapeNets/volumetric_data
# Out:
# airplane   bowl     desk	keyboard     person	 sofa	 tv_stand
# bathtub    car	    door	lamp	     piano	 stairs  vase
# bed	   chair    dresser	laptop	     plant	 stool	 wardrobe
# bench	   cone     flower_pot	mantel	     radio	 table	 xbox
# bookshelf  cup	    glass_box	monitor      range_hood  tent
# bottle	   curtain  guitar	night_stand  sink	 toilet

# %%
obj='airplane'
path=f'/root/.keras/datasets/3DShapeNets/volumetric_data/{obj}/30/test/'
airplane= listdir(f'/root/.keras/datasets/3DShapeNets/volumetric_data/{obj}/30/test')
#!ls /root/.keras/datasets/3DShapeNets/volumetric_data/airplane/30/test

# %%
import scipy.io as IO
import glob
import scipy.ndimage as ND

# %%
voxels=IO.loadmat(path+airplane[8])['instance']

# %%
import matplotlib.pyplot as plt

# %%
z, x, y = voxels.nonzero()
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, -z, zdir='z')

# %%
# !ls /root/.keras/datasets/3DShapeNets/volumetric_data
# Out:
# airplane   bowl     desk	keyboard     person	 sofa	 tv_stand
# bathtub    car	    door	lamp	     piano	 stairs  vase
# bed	   chair    dresser	laptop	     plant	 stool	 wardrobe
# bench	   cone     flower_pot	mantel	     radio	 table	 xbox
# bookshelf  cup	    glass_box	monitor      range_hood  tent
# bottle	   curtain  guitar	night_stand  sink	 toilet

# %%
obj='cone'
path=f'/root/.keras/datasets/3DShapeNets/volumetric_data/{obj}/30/test/'
object_class= listdir(f'/root/.keras/datasets/3DShapeNets/volumetric_data/{obj}/30/test')
#!ls /root/.keras/datasets/3DShapeNets/volumetric_data/airplane/30/test
voxels=IO.loadmat(path+object_class[3])['instance']
z, x, y = voxels.nonzero()
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, zdir='z')
